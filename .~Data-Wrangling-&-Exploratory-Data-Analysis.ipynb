# %% [markdown]
# # TMDB Movie Data set Analysis
# <a id='TMDB_Movie_Data_set_Analysis'></a>

# %% [markdown]
# **By: Sathwik Kesappragada**

# %% [markdown]
# ## Table of Contents<a id='Table_of_Contents'></a>
# * [1 TMDB Movie Data set Analysis](#1_TMDB_Movie_Data_set_Analysis)
#     * [1.1 Table of Contents](#1.1_Table_of_Contents)
#     * [1.2 Introduction](#1.2_Introduction)
#     * [1.3 Imports](#1.3_Imports)
#     * [1.4 Load Data](#1.4_Load_Data)
#     * [1.5 Data Wrangling & Exploration](#1.5_Data_Wrangling_&_Exploration)
#         * [1.5.1 Columns/Features](#1.5.1_Columns_/_Features)
#         * [1.5.2 Number of Missing Values by Column ](#1.5.2_Number_of_Missing_Values_by_Column)
#         * [1.5.3 Searching for Duplicates](#1.5.3_Searching_for_Duplicates)
#         * [1.5.4 Oldest Film](#1.5.4_Oldest_Film)
#         * [1.5.5 Most Recent Film](#1.5.5_Most_Recent_Film)
#         * [1.5.6 Movie Count by Year](#1.5.6_Movie_Count_by_Year)
#         * [1.5.7 Movie Count by Month](#1.5.7_Movie_Count_by_Month)
#         * [1.5.8 Number of Zeros by Column](#1.5.8_Number_of_Zeros_by_Column)
#         * [1.5.9 Number of Genres per Movie](#1.5.9_Number_of_Genres_per_Movie)
#     * [1.6 Exploratory Data Analysis](#1.6_Exploratory_Data_Analysis)
#         * [1.6.1 Top 10](#1.6.1_Top_10)
#             * [1.6.1.1 Languages](#1.6.1.1_Languages)
#             * [1.6.1.2 Popularity](#1.6.1.2_Popularity)
#             * [1.6.1.3 Vote Count](#1.6.1.3_Vote_Count)
#             * [1.6.1.4 Grossed](#1.6.1.4_Grossed)
#             * [1.6.1.5 Budgeted](#1.6.1.5_Budgeted)
#             * [1.6.1.6 Shortest in Duration](#1.6.1.6_Shortest_in_Duration)
#         * [1.6.2 Movies with One Genre](#1.6.2_Movies_with_One_Genre)
#             * [1.6.2.1 Genres vs Vote Average Boxplot](#1.6.2.1_Genres_vs_Vote_Average_Boxplot)
#             * [1.6.2.2 Genres vs Popularity Boxplot](#1.6.2.2_Genres_vs_Popularity_Boxplot)
#             * [1.6.2.3 Genres vs Runtime Boxplot](#1.6.2.3_Genres_vs_Runtime_Boxplot)
#             * [1.6.2.4 Genres vs Vote Count Stripplot](#1.6.2.4_Genres_vs_Vote_Count_Stripplot)
#             * [1.6.2.5 Genres vs Revenue Stripplot](#1.6.2.5_Genres_vs_Revenue_Stripplot)
#             * [1.6.2.6 Popularity vs Vote Average Linear Regression](#1.6.2.6_Popularity_vs_Vote_Average_Linear_Regression)
#             * [1.6.2.7 Budget vs Vote Average Linear Regression](#1.6.2.7_Budget_vs_Vote_Average_Linear_Regression)
#             * [1.6.2.8 Vote Count vs Vote Average Linear Regression](#1.6.2.8_Vote_Count_vs_Vote_Average_Linear_Regression)
#             * [1.6.2.9 Popularity vs Revenue Residual Plot](#1.6.2.9_Popularity_vs_Revenue_Residual_Plot)
#             * [1.6.2.10 Budget vs Revenue Regression Plot](#1.6.2.10_Budget_vs_Vote_Count_Regression_Plot)
#             * [1.6.2.11 Popularity vs Vote Count Jointplot](#1.6.2.11_Popularity_vs_Vote_Count_Jointplot)
#     * [1.7 Ratings](#1.7_Ratings)
#     * [1.8 Saving the Data](#1.8_Saving_the_Data)

# %% [markdown]
# ## Introduction<a id='1.2_Introduction'></a>

# %% [markdown]
# ***Lights................!!! Camera....................!!!Action!***

# %% [markdown]
# The concept of film started by mere accident with

# %% [markdown]
# Does the recommended section provide satisfaction? Are the movie suggestions popping up elevate anyone’s mood? Do the advertisements appearing in between Instagram posts catch anybody’s attention? Is there a system that gives better movie suggestions?

# %% [markdown]
# From the moment an individual unlocks his/her phone till the moment he/she puts it away, every action being committed is tracked and monitored, stored into data, that is confidential information sold to big corporations. Pew Research states that 81% of Americans own smartphones creating a push for relevant and accurate promotions that will influence a user’s decision-making process and attract customers. With complex supervision, people with smartphones are being schemed to stay on their cellular devices for longer periods of time to generate more revenue. Why? Companies with money can afford exceptional marketing. According to Business Wire, 60% of consumers click on cellphone ads every week suggesting how prevalent mobile advertising has become. Given these points, everyone is simply surrounded by recommender systems; people are constantly getting pitched ideas. From a simple Google search to a YouTube video to a Netflix original and to a song on Spotify, there exists a machine that advises its user based off of abundant data.

# %% [markdown]
# add pictures

# %% [markdown]
# ## Imports<a id='1.3_Imports'></a>

# %%
#import modules and their subpackages required for analysis
import sys
import ast
import pandas as pd
import matplotlib.pyplot as plt 
from datetime import datetime
import numpy as np
from ast import literal_eval
import seaborn as sns
import os
import missingno as msno

# %% [markdown]
# ## Load Data<a id='1.4_Load_Data'></a>

# %%
#load data into variable
movies = pd.read_csv('C:/Users/sathw/OneDrive/Desktop/Springboard_work/IMDB-Movie-Ratings/rawdata/movies_metadata.csv', index_col = 'title', low_memory = False, nrows = 46000)
movies.head()
# Out:
#                              adult  \
# title
# Toy Story                    FALSE
# Jumanji                      FALSE
# Grumpier Old Men             FALSE
# Waiting to Exhale            FALSE
# Father of the Bride Part II  FALSE
#
#                                                          belongs_to_collection  \
# title
# Toy Story                    {'id': 10194, 'name': 'Toy Story Collection', ...
# Jumanji                                                                    NaN
# Grumpier Old Men             {'id': 119050, 'name': 'Grumpy Old Men Collect...
# Waiting to Exhale                                                          NaN
# Father of the Bride Part II  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                                budget  \
# title
# Toy Story                    30000000
# Jumanji                      65000000
# Grumpier Old Men                    0
# Waiting to Exhale            16000000
# Father of the Bride Part II         0
#
#                                                                         genres  \
# title
# Toy Story                    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# Jumanji                      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# Grumpier Old Men             [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# Waiting to Exhale            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# Father of the Bride Part II                     [{'id': 35, 'name': 'Comedy'}]
#
#                                                          homepage     id  \
# title
# Toy Story                    http://toystory.disney.com/toy-story    862
# Jumanji                                                       NaN   8844
# Grumpier Old Men                                              NaN  15602
# Waiting to Exhale                                             NaN  31357
# Father of the Bride Part II                                   NaN  11862
#
#                                imdb_id original_language  \
# title
# Toy Story                    tt0114709                en
# Jumanji                      tt0113497                en
# Grumpier Old Men             tt0113228                en
# Waiting to Exhale            tt0114885                en
# Father of the Bride Part II  tt0113041                en
#
#                                           original_title  \
# title
# Toy Story                                      Toy Story
# Jumanji                                          Jumanji
# Grumpier Old Men                        Grumpier Old Men
# Waiting to Exhale                      Waiting to Exhale
# Father of the Bride Part II  Father of the Bride Part II
#
#                                                                       overview  \
# title
# Toy Story                    Led by Woody, Andy's toys live happily in his ...
# Jumanji                      When siblings Judy and Peter discover an encha...
# Grumpier Old Men             A family wedding reignites the ancient feud be...
# Waiting to Exhale            Cheated on, mistreated and stepped on, the wom...
# Father of the Bride Part II  Just when George Banks has recovered from his ...
#
#                              ...  \
# title                        ...
# Toy Story                    ...
# Jumanji                      ...
# Grumpier Old Men             ...
# Waiting to Exhale            ...
# Father of the Bride Part II  ...
#
#                                                           production_countries  \
# title
# Toy Story                    [{'iso_3166_1': 'US', 'name': 'United States o...
# Jumanji                      [{'iso_3166_1': 'US', 'name': 'United States o...
# Grumpier Old Men             [{'iso_3166_1': 'US', 'name': 'United States o...
# Waiting to Exhale            [{'iso_3166_1': 'US', 'name': 'United States o...
# Father of the Bride Part II  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                             release_date      revenue runtime  \
# title
# Toy Story                     10/30/1995  373554033.0    81.0
# Jumanji                       12/15/1995  262797249.0   104.0
# Grumpier Old Men              12/22/1995          0.0   101.0
# Waiting to Exhale             12/22/1995   81452156.0   127.0
# Father of the Bride Part II    2/10/1995   76578911.0   106.0
#
#                                                               spoken_languages  \
# title
# Toy Story                             [{'iso_639_1': 'en', 'name': 'English'}]
# Jumanji                      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# Grumpier Old Men                      [{'iso_639_1': 'en', 'name': 'English'}]
# Waiting to Exhale                     [{'iso_639_1': 'en', 'name': 'English'}]
# Father of the Bride Part II           [{'iso_639_1': 'en', 'name': 'English'}]
#
#                                status  \
# title
# Toy Story                    Released
# Jumanji                      Released
# Grumpier Old Men             Released
# Waiting to Exhale            Released
# Father of the Bride Part II  Released
#
#                                                                        tagline  \
# title
# Toy Story                                                                  NaN
# Jumanji                              Roll the dice and unleash the excitement!
# Grumpier Old Men             Still Yelling. Still Fighting. Still Ready for...
# Waiting to Exhale            Friends are the people who let you be yourself...
# Father of the Bride Part II  Just When His World Is Back To Normal... He's ...
#
#                              video vote_average vote_count
# title
# Toy Story                    False          7.7     5415.0
# Jumanji                      False          6.9     2413.0
# Grumpier Old Men             False          6.5       92.0
# Waiting to Exhale            False          6.1       34.0
# Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 23 columns]

# %% [markdown]
# Here we get a sneak peak at what the movies data is looking like. Movies are listed with their characteristics.

# %% [markdown]
# ## Data Wrangling & Exploration<a id='1.5_Data_Wrangling_&_Exploration'></a>

# %%
#45466 movies 
movies.shape
# Out:
# (45466, 23)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45466 entries, Toy Story to Queerama
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  video                  45460 non-null  object
#  21  vote_average           45460 non-null  float64
#  22  vote_count             45460 non-null  float64
# dtypes: float64(4), object(19)
# memory usage: 8.3+ MB

# %% [markdown]
# ### Columns/Features<a id='1.5.1_Columns_/_Features'></a>
# - **adult**: specifies whether the film is X-Rated or Adult
# - **belongs_to_collection**: identifies the movie series/franchise a film belongs to (Toy Story, Harry Potter)
# - **budget**: budget of the film in dollars
# - **genres**: genres/classes associated with each movie
# - **homepage**: official homepage of the movie
# - **id**: movie ID
# - **imdb_id**: IMDB ID of the film
# - **original_language**: the language the film was officially shot in
# - **original_title**: the name of the movie upon release
# - **overview**: brief summary of the plot
# - **popularity**: popularity score that indicates how well known the film is
# - **poster_path**: URL of the movie poster image
# - **production_companies**: companies involved in the making of the film
# - **production_countries**: countries where the movie was released/shot in
# - **release_date**: theatrical release date
# - **revenue**: total return of the film
# - **runtime**: number in minutes length of film
# - **spoken_languages**: languages spoken in the film
# - **status**: state of film (Released, Rumored, Post-Production, etc.)
# - **tagline**: punch line/catch phrase
# - **video**: expresses whether or not if there is a video of the film present on TMDB
# - **vote_average**: average score of the movie
# - **vote_count**: the number of votes by users

# %%
movies.id.value_counts()
# Out:
# 141971    3
# 77221     2
# 15028     2
# 4912      2
# 110428    2
#          ..
# 17831     1
# 10654     1
# 240913    1
# 64725     1
# 67327     1
# Name: id, Length: 45436, dtype: int64

# %% [markdown]
# Dtypes of some of these features are incorrectly classified and need to be corrected moving forward to be able to conduct any analysis. For example,

# %%
type(movies['budget'].iloc[0])
# Out:
# str

# %%
type(movies['popularity'].iloc[0])
# Out:
# str

# %%
type(movies['genres'].iloc[0])
# Out:
# str

# %%
movies['budget'] = pd.to_numeric(movies['budget'], errors='coerce')
movies['popularity'] = pd.to_numeric(movies['popularity'], errors = 'coerce')

# %%
#returns all movie titles
movies.index
# Out:
# Index([                  'Toy Story',                     'Jumanji',
#                   'Grumpier Old Men',           'Waiting to Exhale',
#        'Father of the Bride Part II',                        'Heat',
#                            'Sabrina',                'Tom and Huck',
#                       'Sudden Death',                   'GoldenEye',
#        ...
#                   'House of Horrors',   'Shadow of the Blair Witch',
#                'The Burkittsville 7',             'Caged Heat 3000',
#                         'Robin Hood',                      'Subdue',
#                'Century of Birthing',                    'Betrayal',
#                   'Satan Triumphant',                    'Queerama'],
#       dtype='object', name='title', length=45466)

# %% [markdown]
# **using transpose we can clearly see the data listed for each movie**

# %%
#looking at one record and all of its information
movies[movies.original_title == 'Toy Story'].transpose()
# Out:
# title                                                          Toy Story
# adult                                                              FALSE
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                             3e+07
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.9469
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# production_companies      [{'name': 'Pixar Animation Studios', 'id': 3}]
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  10/30/1995
# revenue                                                      3.73554e+08
# runtime                                                               81
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                                              NaN
# video                                                              False
# vote_average                                                         7.7
# vote_count                                                          5415

# %%
def clean_col(df,col):
    """ 
    @ params: dataframe, column
    removes irrelevant information and outputs only list of the names in each dictionary
    """
    df[col] = df[col].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else[])

# %%
cols = ['genres', 'production_countries', 'spoken_languages']
for col in cols:
    clean_col(movies, col)

# %%
movies.applymap(lambda x: isinstance(x,list)).all()
# Out:
# adult                    False
# belongs_to_collection    False
# budget                   False
# genres                    True
# homepage                 False
# id                       False
# imdb_id                  False
# original_language        False
# original_title           False
# overview                 False
# popularity               False
# poster_path              False
# production_companies     False
# production_countries      True
# release_date             False
# revenue                  False
# runtime                  False
# spoken_languages          True
# status                   False
# tagline                  False
# video                    False
# vote_average             False
# vote_count               False
# dtype: bool

# %% [markdown]
# ### Number of Missing Values by Column<a id='1.5.2_Number_of_Missing_Values_by_Column'></a>

# %%
#checking how many null values there are for each column/feature
missing = pd.concat([movies.isnull().sum(), 100 * movies.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='%', ascending = False)
# Out:
#                        count          %
# belongs_to_collection  40972  90.115691
# homepage               37684  82.883913
# tagline                25054  55.104914
# overview                 954   2.098271
# poster_path              386   0.848986
# runtime                  263   0.578454
# release_date              87   0.191352
# status                    87   0.191352
# imdb_id                   17   0.037391
# original_language         11   0.024194
# vote_average               6   0.013197
# video                      6   0.013197
# revenue                    6   0.013197
# vote_count                 6   0.013197
# popularity                 6   0.013197
# production_companies       3   0.006598
# budget                     3   0.006598
# production_countries       0   0.000000
# spoken_languages           0   0.000000
# original_title             0   0.000000
# id                         0   0.000000
# genres                     0   0.000000
# adult                      0   0.000000

# %%
msno.matrix(movies)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
movies[movies.vote_count.isnull()]
# Out:
#                                                    adult  \
# title
# NaN                                                FALSE
# NaN                                   - Written by Ørnås
# NaN                                                FALSE
# NaN     Rune Balot goes to a casino connected to the ...
# NaN                                                FALSE
# NaN     Avalanche Sharks tells the story of a bikini ...
#
#                                    belongs_to_collection  budget  \
# title
# NaN                                                  NaN     0.0
# NaN                                             0.065736     NaN
# NaN    {'id': 122661, 'name': 'Mardock Scramble Colle...     0.0
# NaN                                             1.931659     NaN
# NaN                                                  NaN     0.0
# NaN                                             2.185485     NaN
#
#                                                   genres  \
# title
# NaN                            [Action, Thriller, Drama]
# NaN    [Carousel Productions, Vision View Entertainme...
# NaN                         [Animation, Science Fiction]
# NaN    [Aniplex, GoHands, BROSTA TV, Mardock Scramble...
# NaN          [TV Movie, Action, Horror, Science Fiction]
# NaN    [Odyssey Media, Pulser Productions, Rogue Stat...
#
#                                                 homepage         id  \
# title
# NaN                                                  NaN      82663
# NaN    [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  8/20/1997
# NaN                        http://m-scramble.jp/exhaust/     122662
# NaN    [{'iso_3166_1': 'US', 'name': 'United States o...  9/29/2012
# NaN                                                  NaN     249260
# NaN             [{'iso_3166_1': 'CA', 'name': 'Canada'}]   1/1/2014
#
#          imdb_id original_language                            original_title  \
# title
# NaN    tt0113002                en                              Midnight Man
# NaN            0               104  [{'iso_639_1': 'en', 'name': 'English'}]
# NaN    tt2423504                ja                          マルドゥック・スクランブル 排気
# NaN            0                68      [{'iso_639_1': 'ja', 'name': '日本語'}]
# NaN    tt2622826                en                          Avalanche Sharks
# NaN            0                82  [{'iso_639_1': 'en', 'name': 'English'}]
#
#                                                 overview  ...  \
# title                                                     ...
# NaN    British soldiers force a recently captured IRA...  ...
# NaN                                             Released  ...
# NaN           Third film of the Mardock Scramble series.  ...
# NaN                                             Released  ...
# NaN    A group of skiers are terrorized during spring...  ...
# NaN                                             Released  ...
#
#        production_countries release_date revenue runtime spoken_languages  \
# title
# NaN                      []          NaN     NaN     NaN               []
# NaN                      []            1     NaN     NaN               []
# NaN                      []          NaN     NaN     NaN               []
# NaN                      []           12     NaN     NaN               []
# NaN                      []          NaN     NaN     NaN               []
# NaN                      []           22     NaN     NaN               []
#
#        status  tagline video vote_average vote_count
# title
# NaN       NaN      NaN   NaN          NaN        NaN
# NaN       NaN      NaN   NaN          NaN        NaN
# NaN       NaN      NaN   NaN          NaN        NaN
# NaN       NaN      NaN   NaN          NaN        NaN
# NaN       NaN      NaN   NaN          NaN        NaN
# NaN       NaN      NaN   NaN          NaN        NaN
#
# [6 rows x 23 columns]

# %%
movies = movies[~movies.vote_count.isnull()]

# %%
movies.shape
# Out:
# (45460, 23)

# %%
movies[movies['vote_average'].isna()]
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ### Searching for Duplicates<a id='1.5.3_Searching_for_Duplicates'></a>

# %%
#looking for duplicates in movie title
movies['original_title'].value_counts().head(15)
# Out:
# Hamlet                           8
# Alice in Wonderland              8
# Les Misérables                   7
# Macbeth                          7
# Cinderella                       7
# The Three Musketeers             7
# A Christmas Carol                7
# Frankenstein                     6
# King Lear                        6
# Jane Eyre                        6
# Wuthering Heights                6
# The Hound of the Baskervilles    6
# Treasure Island                  6
# Heidi                            6
# Blackout                         6
# Name: original_title, dtype: int64

# %%
#sometimes movies with the same title are released
#you can tell theyre different by looking at release dates
movies[movies['original_title'] == 'Macbeth'].transpose()
# Out:
# title                                                            Macbeth  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                           [Drama]
# homepage                                                             NaN
# id                                                                 27883
# imdb_id                                                        tt0040558
# original_language                                                     en
# original_title                                                   Macbeth
# overview               Orson Welles' unique take on Shakespeare's cla...
# popularity                                                       1.66377
# poster_path                             /dBGn1Mj1IcmfqnykjnQDvDe0B9C.jpg
# production_companies         [{'name': 'Republic Pictures', 'id': 1432}]
# production_countries                          [United States of America]
# release_date                                                   10/1/1948
# revenue                                                                0
# runtime                                                              107
# spoken_languages                                               [English]
# status                                                          Released
# tagline                Entertainment Greatness . . . That Only Motion...
# video                                                              False
# vote_average                                                         6.7
# vote_count                                                            21
#
# title                                                            Macbeth  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                           [Drama]
# homepage                                                             NaN
# id                                                                115427
# imdb_id                                                        tt0292081
# original_language                                                     hu
# original_title                                                   Macbeth
# overview               A Hungarian TV version of the play shot in jus...
# popularity                                                      0.017296
# poster_path                               /MXwwQjLWEfpPiY33XUqIRsOKk.jpg
# production_companies                                                  []
# production_countries                                           [Hungary]
# release_date                                                    1/1/1982
# revenue                                                                0
# runtime                                                               72
# spoken_languages                                                [Magyar]
# status                                                          Released
# tagline                                                              NaN
# video                                                              False
# vote_average                                                          10
# vote_count                                                             1
#
# title                                                            Macbeth  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                        [Thriller]
# homepage                                                             NaN
# id                                                                119844
# imdb_id                                                        tt0084284
# original_language                                                     en
# original_title                                                   Macbeth
# overview               Macbeth and his wife murder Duncan in order to...
# popularity                                                      0.328289
# poster_path                             /zsKAHJ5J4sHY8P2K9HncGuXhNVI.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                   11/5/1983
# revenue                                                                0
# runtime                                                              147
# spoken_languages                                                      []
# status                                                          Released
# tagline                                                              NaN
# video                                                              False
# vote_average                                                         5.8
# vote_count                                                             2
#
# title                                                            Macbeth  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                         [Thriller, Drama, Action]
# homepage                                                             NaN
# id                                                                 13775
# imdb_id                                                        tt0434541
# original_language                                                     en
# original_title                                                   Macbeth
# overview               Macbeth, loyal to his crime boss, Duncan, is t...
# popularity                                                        1.8337
# poster_path                             /fWoQSPnlycOiUmbJdcpdTLtATum.jpg
# production_companies                                                  []
# production_countries                                         [Australia]
# release_date                                                   9/21/2006
# revenue                                                                0
# runtime                                                              109
# spoken_languages                                               [English]
# status                                                          Released
# tagline                                 Something wicked this way comes.
# video                                                              False
# vote_average                                                         3.9
# vote_count                                                            11
#
# title                                                            Macbeth  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                           1.5e+07
# genres                                             [History, Drama, War]
# homepage                                   http://www.macbeth-movie.com/
# id                                                                225728
# imdb_id                                                        tt2884018
# original_language                                                     en
# original_title                                                   Macbeth
# overview               Feature film adaptation of Shakespeare's Scott...
# popularity                                                       12.4935
# poster_path                             /417tcPgyz8oatgp1WE0SZZ4Odgl.jpg
# production_companies   [{'name': 'Studio Canal', 'id': 5870}, {'name'...
# production_countries   [France, United Kingdom, United States of Amer...
# release_date                                                   8/16/2015
# revenue                                                      1.26017e+07
# runtime                                                              113
# spoken_languages                                               [English]
# status                                                          Released
# tagline                              All hail Macbeth that shall be king
# video                                                              False
# vote_average                                                         6.4
# vote_count                                                           497
#
# title                                           A Performance of Macbeth  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                  [Drama, Foreign]
# homepage                                                             NaN
# id                                                                 41149
# imdb_id                                                        tt0079499
# original_language                                                     en
# original_title                                                   Macbeth
# overview               Shakespeare's classic tragedy of ambition, wit...
# popularity                                                      0.398025
# poster_path                             /agLf7tTuTPW1RGf4J2btTjkaxLw.jpg
# production_companies   [{'name': 'Royal Shakespeare Company', 'id': 5...
# production_countries                                    [United Kingdom]
# release_date                                                    2/2/1979
# revenue                                                                0
# runtime                                                              145
# spoken_languages                                               [English]
# status                                                          Released
# tagline                                                              NaN
# video                                                              False
# vote_average                                                           5
# vote_count                                                             2
#
# title                                                            Macbeth
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                           [Drama]
# homepage                                                             NaN
# id                                                                133448
# imdb_id                                                        tt1570337
# original_language                                                     en
# original_title                                                   Macbeth
# overview               Part of the PBS Great Performance Series. Reno...
# popularity                                                       1.15917
# poster_path                             /8nFuFOHZTYVldpFFHNNMnM9234X.jpg
# production_companies   [{'name': 'PBS', 'id': 5826}, {'name': 'BBC', ...
# production_countries                                    [United Kingdom]
# release_date                                                   10/6/2010
# revenue                                                                0
# runtime                                                              160
# spoken_languages                                               [English]
# status                                                          Released
# tagline                                                              NaN
# video                                                              False
# vote_average                                                         6.9
# vote_count                                                             9

# %%
#another method to identify duplicates 
(movies['original_title'] + ', ' + movies['release_date']).value_counts()
# Out:
# Blackout, 12/26/2008                                                                             3
# The Congress, 5/16/2013                                                                          2
# Why We Fight: Divide and Conquer, 1/1/1943                                                       2
# Le Samouraï, 10/25/1967                                                                          2
# รักที่ขอนแก่น, 9/2/2015                                                                          2
#                                                                                                 ..
# Careful What You Wish For, 5/6/2015                                                              1
# Journey to Space, 2/13/2015                                                                      1
# Universal Soldier: The Return, 8/5/1999                                                          1
# Cut!, 1/14/2014                                                                                  1
# The Incredibly Strange Creatures Who Stopped Living and Became Mixed-Up Zombies!!?, 2/10/1964    1
# Length: 45346, dtype: int64

# %% [markdown]
# A way to identify duplicates within the data set was by checking unique values in combos.
# Movies that share the same title and release date are repeating records that needs to be dropped.

# %%
#literally everything is same
movies[movies['original_title'] == 'Blackout'].transpose()
# Out:
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                               [Thriller, Mystery]
# homepage                                                             NaN
# id                                                                141971
# imdb_id                                                        tt1180333
# original_language                                                     fi
# original_title                                                  Blackout
# overview               Recovering from a nail gun shot to the head an...
# popularity                                                      0.411949
# poster_path                             /8VSZ9coCzxOCW2wE2Qene1H1fKO.jpg
# production_companies      [{'name': 'Filmiteollisuus Fine', 'id': 5166}]
# production_countries                                           [Finland]
# release_date                                                  12/26/2008
# revenue                                                                0
# runtime                                                              108
# spoken_languages                                                 [suomi]
# status                                                          Released
# tagline                Which one is the first to return - memory or t...
# video                                                              False
# vote_average                                                         6.7
# vote_count                                                             3
#
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                               [Thriller, Mystery]
# homepage                                                             NaN
# id                                                                141971
# imdb_id                                                        tt1180333
# original_language                                                     fi
# original_title                                                  Blackout
# overview               Recovering from a nail gun shot to the head an...
# popularity                                                      0.411949
# poster_path                             /8VSZ9coCzxOCW2wE2Qene1H1fKO.jpg
# production_companies      [{'name': 'Filmiteollisuus Fine', 'id': 5166}]
# production_countries                                           [Finland]
# release_date                                                  12/26/2008
# revenue                                                                0
# runtime                                                              108
# spoken_languages                                                 [suomi]
# status                                                          Released
# tagline                Which one is the first to return - memory or t...
# video                                                              False
# vote_average                                                         6.7
# vote_count                                                             3
#
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                               [Thriller, Mystery]
# homepage                                                             NaN
# id                                                                141971
# imdb_id                                                        tt1180333
# original_language                                                     fi
# original_title                                                  Blackout
# overview               Recovering from a nail gun shot to the head an...
# popularity                                                      0.411949
# poster_path                             /8VSZ9coCzxOCW2wE2Qene1H1fKO.jpg
# production_companies      [{'name': 'Filmiteollisuus Fine', 'id': 5166}]
# production_countries                                           [Finland]
# release_date                                                  12/26/2008
# revenue                                                                0
# runtime                                                              108
# spoken_languages                                                 [suomi]
# status                                                          Released
# tagline                Which one is the first to return - memory or t...
# video                                                              False
# vote_average                                                         6.7
# vote_count                                                             3
#
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                [Action, Thriller]
# homepage                                                             NaN
# id                                                                100063
# imdb_id                                                        tt0077241
# original_language                                                     en
# original_title                                                  Blackout
# overview               A black comedy of violent criminals who terror...
# popularity                                                      0.314595
# poster_path                             /ddyDGQBLbG1LjK01dz9Nb1NQstf.jpg
# production_companies                                                  []
# production_countries                          [United States of America]
# release_date                                                   8/25/1978
# revenue                                                                0
# runtime                                                               92
# spoken_languages                                               [English]
# status                                                          Released
# tagline                The night the power failed.... and the shock b...
# video                                                              False
# vote_average                                                           5
# vote_count                                                             1
#
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                [Horror, Thriller]
# homepage                                                             NaN
# id                                                                226630
# imdb_id                                                        tt0088816
# original_language                                                     en
# original_title                                                  Blackout
# overview               A police officer suspects that a local husband...
# popularity                                                       1.01854
# poster_path                             /cGL5nCdUdsQraT6qvzQIWw7wkk2.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                   7/28/1985
# revenue                                                                0
# runtime                                                              100
# spoken_languages                                               [English]
# status                                                          Released
# tagline                        His obsession would become her nightmare.
# video                                                              False
# vote_average                                                         4.4
# vote_count                                                             5
#
# title                                                           Blackout
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                     [Documentary]
# homepage               http://www.pbs.org/wgbh/americanexperience/fil...
# id                                                                416951
# imdb_id                                                        tt4284046
# original_language                                                     en
# original_title                                                  Blackout
# overview               First responders, journalists, shop owners, th...
# popularity                                                      0.423677
# poster_path                             /jH13IMZZlyk0f7G6eQLycn0JLgM.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                   7/14/2015
# revenue                                                                0
# runtime                                                               53
# spoken_languages                                               [English]
# status                                                          Released
# tagline                                                              NaN
# video                                                              False
# vote_average                                                         6.7
# vote_count                                                             3

# %%
movies[['original_title', 'release_date']].nunique()
# Out:
# original_title    43367
# release_date      17333
# dtype: int64

# %%
movies = movies.drop_duplicates(subset=['original_title', 'release_date'])

# %%
(movies['original_title'] + ', ' + movies['release_date']).value_counts()
# Out:
# The Master of Disguise, 8/2/2002                                                                 1
# M. Butterfly, 9/9/1993                                                                           1
# Brian Posehn: The Fartist, 3/1/2013                                                              1
# ABCs of Death 2.5, 8/2/2016                                                                      1
# I sette gladiatori, 10/11/1962                                                                   1
#                                                                                                 ..
# That Thing You Do!, 10/4/1996                                                                    1
# Qualche nuvola, 9/6/2011                                                                         1
# Le Mépris, 10/21/1963                                                                            1
# Careful What You Wish For, 5/6/2015                                                              1
# The Incredibly Strange Creatures Who Stopped Living and Became Mixed-Up Zombies!!?, 2/10/1964    1
# Length: 45346, dtype: int64

# %%
movies[movies['original_title']=='Blackout'].transpose()
# Out:
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                               [Thriller, Mystery]
# homepage                                                             NaN
# id                                                                141971
# imdb_id                                                        tt1180333
# original_language                                                     fi
# original_title                                                  Blackout
# overview               Recovering from a nail gun shot to the head an...
# popularity                                                      0.411949
# poster_path                             /8VSZ9coCzxOCW2wE2Qene1H1fKO.jpg
# production_companies      [{'name': 'Filmiteollisuus Fine', 'id': 5166}]
# production_countries                                           [Finland]
# release_date                                                  12/26/2008
# revenue                                                                0
# runtime                                                              108
# spoken_languages                                                 [suomi]
# status                                                          Released
# tagline                Which one is the first to return - memory or t...
# video                                                              False
# vote_average                                                         6.7
# vote_count                                                             3
#
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                [Action, Thriller]
# homepage                                                             NaN
# id                                                                100063
# imdb_id                                                        tt0077241
# original_language                                                     en
# original_title                                                  Blackout
# overview               A black comedy of violent criminals who terror...
# popularity                                                      0.314595
# poster_path                             /ddyDGQBLbG1LjK01dz9Nb1NQstf.jpg
# production_companies                                                  []
# production_countries                          [United States of America]
# release_date                                                   8/25/1978
# revenue                                                                0
# runtime                                                               92
# spoken_languages                                               [English]
# status                                                          Released
# tagline                The night the power failed.... and the shock b...
# video                                                              False
# vote_average                                                           5
# vote_count                                                             1
#
# title                                                           Blackout  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                [Horror, Thriller]
# homepage                                                             NaN
# id                                                                226630
# imdb_id                                                        tt0088816
# original_language                                                     en
# original_title                                                  Blackout
# overview               A police officer suspects that a local husband...
# popularity                                                       1.01854
# poster_path                             /cGL5nCdUdsQraT6qvzQIWw7wkk2.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                   7/28/1985
# revenue                                                                0
# runtime                                                              100
# spoken_languages                                               [English]
# status                                                          Released
# tagline                        His obsession would become her nightmare.
# video                                                              False
# vote_average                                                         4.4
# vote_count                                                             5
#
# title                                                           Blackout
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                     [Documentary]
# homepage               http://www.pbs.org/wgbh/americanexperience/fil...
# id                                                                416951
# imdb_id                                                        tt4284046
# original_language                                                     en
# original_title                                                  Blackout
# overview               First responders, journalists, shop owners, th...
# popularity                                                      0.423677
# poster_path                             /jH13IMZZlyk0f7G6eQLycn0JLgM.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                   7/14/2015
# revenue                                                                0
# runtime                                                               53
# spoken_languages                                               [English]
# status                                                          Released
# tagline                                                              NaN
# video                                                              False
# vote_average                                                         6.7
# vote_count                                                             3

# %%
movies['release_date'] = pd.to_datetime(movies['release_date'], errors = 'coerce')
oldest_movie_bydate = movies.release_date.min()
most_recent_bydate = movies.release_date.max()

# %%
print(oldest_movie_bydate)
print(most_recent_bydate)
# Out:
# 1874-12-09 00:00:00
# 2020-12-16 00:00:00

# %% [markdown]
# ### Oldest Film<a id='1.5.4_Oldest_Film'></a>

# %%
movies[movies['release_date'] == oldest_movie_bydate]
# Out:
#                   adult belongs_to_collection  budget         genres homepage  \
# title
# Passage of Venus  FALSE                   NaN     0.0  [Documentary]      NaN
#
#                       id    imdb_id original_language    original_title  \
# title
# Passage of Venus  315946  tt3155794                xx  Passage de Venus
#
#                                                            overview  ...  \
# title                                                                ...
# Passage of Venus  Photo sequence of the rare transit of Venus ov...  ...
#
#                   production_countries release_date revenue runtime  \
# title
# Passage of Venus              [France]   1874-12-09     0.0     1.0
#
#                  spoken_languages    status  tagline  video vote_average  \
# title
# Passage of Venus    [No Language]  Released      NaN  False          6.0
#
#                  vote_count
# title
# Passage of Venus       19.0
#
# [1 rows x 23 columns]

# %% [markdown]
# ### Most Recent Film<a id='1.5.5_Most_Recent_Film'></a>

# %%
movies[movies['release_date'] == most_recent_bydate]
# Out:
#           adult                              belongs_to_collection  budget  \
# title
# Avatar 2  FALSE  {'id': 87096, 'name': 'Avatar Collection', 'po...     0.0
#
#                                                  genres  \
# title
# Avatar 2  [Action, Adventure, Fantasy, Science Fiction]
#
#                              homepage     id    imdb_id original_language  \
# title
# Avatar 2  http://www.avatarmovie.com/  76600  tt1630029                en
#
#          original_title                    overview  ...  \
# title                                                ...
# Avatar 2       Avatar 2  A sequel to Avatar (2009).  ...
#
#                 production_countries release_date revenue runtime  \
# title
# Avatar 2  [United States of America]   2020-12-16     0.0     0.0
#
#             spoken_languages         status  tagline  video vote_average  \
# title
# Avatar 2  [English, Deutsch]  In Production      NaN  False          0.0
#
#          vote_count
# title
# Avatar 2       58.0
#
# [1 rows x 23 columns]

# %%
movies[movies['release_date'] > '2018-01-01 00:00:00']
# Out:
#                             adult  \
# title
# Avatar 2                    FALSE
# Bad Boys for Life           FALSE
# Iron Sky: The Coming Race   FALSE
# Mary Shelley                FALSE
# The Other Side of the Wind  FALSE
# Mobile Homes                FALSE
#
#                                                         belongs_to_collection  \
# title
# Avatar 2                    {'id': 87096, 'name': 'Avatar Collection', 'po...
# Bad Boys for Life           {'id': 14890, 'name': 'Bad Boys Collection', '...
# Iron Sky: The Coming Race   {'id': 312977, 'name': 'Iron Sky Collection', ...
# Mary Shelley                                                              NaN
# The Other Side of the Wind                                                NaN
# Mobile Homes                                                              NaN
#
#                                 budget  \
# title
# Avatar 2                           0.0
# Bad Boys for Life                  0.0
# Iron Sky: The Coming Race   18000000.0
# Mary Shelley                       0.0
# The Other Side of the Wind  12000000.0
# Mobile Homes                       0.0
#
#                                                                    genres  \
# title
# Avatar 2                    [Action, Adventure, Fantasy, Science Fiction]
# Bad Boys for Life                               [Thriller, Action, Crime]
# Iron Sky: The Coming Race      [Action, Comedy, Fantasy, Science Fiction]
# Mary Shelley                                             [Drama, Romance]
# The Other Side of the Wind                                [Comedy, Drama]
# Mobile Homes                                                      [Drama]
#
#                                                homepage      id    imdb_id  \
# title
# Avatar 2                    http://www.avatarmovie.com/   76600  tt1630029
# Bad Boys for Life                                   NaN   38700  tt1502397
# Iron Sky: The Coming Race       http://www.ironsky.net/  302349  tt3038708
# Mary Shelley                                        NaN  332283  tt3906082
# The Other Side of the Wind                          NaN  299782  tt0069049
# Mobile Homes                                        NaN  412059  tt5613402
#
#                            original_language              original_title  \
# title
# Avatar 2                                  en                    Avatar 2
# Bad Boys for Life                         en           Bad Boys for Life
# Iron Sky: The Coming Race                 en   Iron Sky: The Coming Race
# Mary Shelley                              en                Mary Shelley
# The Other Side of the Wind                en  The Other Side of the Wind
# Mobile Homes                              en                Mobile Homes
#
#                                                                      overview  \
# title
# Avatar 2                                           A sequel to Avatar (2009).
# Bad Boys for Life           The continuing adventures of Miami detectives ...
# Iron Sky: The Coming Race   Twenty years after the events of Iron Sky, the...
# Mary Shelley                The love affair between poet Percy Shelley and...
# The Other Side of the Wind  Orson Welles' unfinished masterpiece, restored...
# Mobile Homes                In forgotten towns along the American border, ...
#
#                             ...                   production_countries  \
# title                       ...
# Avatar 2                    ...             [United States of America]
# Bad Boys for Life           ...             [United States of America]
# Iron Sky: The Coming Race   ...            [Belgium, Finland, Germany]
# Mary Shelley                ...  [Ireland, Luxembourg, United Kingdom]
# The Other Side of the Wind  ...       [Iran, United States of America]
# Mobile Homes                ...                       [France, Canada]
#
#                            release_date revenue runtime    spoken_languages  \
# title
# Avatar 2                     2020-12-16     0.0     0.0  [English, Deutsch]
# Bad Boys for Life            2018-11-07     0.0     0.0           [English]
# Iron Sky: The Coming Race    2018-03-01     0.0     0.0  [English, Deutsch]
# Mary Shelley                 2018-04-25     0.0     0.0           [English]
# The Other Side of the Wind   2018-12-31     0.0     0.0           [English]
# Mobile Homes                 2018-04-04     0.0   105.0           [English]
#
#                                      status  tagline  video vote_average  \
# title
# Avatar 2                      In Production      NaN  False          0.0
# Bad Boys for Life                   Planned      NaN  False          0.0
# Iron Sky: The Coming Race   Post Production      NaN  False          0.0
# Mary Shelley                Post Production      NaN  False          0.0
# The Other Side of the Wind  Post Production      NaN  False          0.0
# Mobile Homes                Post Production      NaN  False          0.0
#
#                            vote_count
# title
# Avatar 2                         58.0
# Bad Boys for Life                12.0
# Iron Sky: The Coming Race         0.0
# Mary Shelley                      1.0
# The Other Side of the Wind        1.0
# Mobile Homes                      1.0
#
# [6 rows x 23 columns]

# %%
movies['adult'].value_counts(normalize=True)
# Out:
# FALSE    0.999802
# TRUE     0.000198
# Name: adult, dtype: float64

# %%
movies['year'] = movies['release_date'].dt.year
movies['year'].head(10)
# Out:
# title
# Toy Story                      1995.0
# Jumanji                        1995.0
# Grumpier Old Men               1995.0
# Waiting to Exhale              1995.0
# Father of the Bride Part II    1995.0
# Heat                           1995.0
# Sabrina                        1995.0
# Tom and Huck                   1995.0
# Sudden Death                   1995.0
# GoldenEye                      1995.0
# Name: year, dtype: float64

# %%
movies['day'] = movies['release_date'].dt.day
movies['month'] = movies['release_date'].dt.month

# %% [markdown]
# ### Movie Count by Year<a id='1.5.6_Movie_Count_by_Year'></a>

# %%
movies.year.value_counts().head(10)
# Out:
# 2014.0    1973
# 2015.0    1904
# 2013.0    1887
# 2012.0    1721
# 2011.0    1666
# 2016.0    1604
# 2009.0    1585
# 2010.0    1501
# 2008.0    1470
# 2007.0    1319
# Name: year, dtype: int64

# %%
count_by_year = movies.groupby('year')['original_title'].count()
plt.figure(figsize=(14,5))
count_by_year.plot()

# %%
movies.month.value_counts().head(10)
# Out:
# 1.0     5909
# 9.0     4834
# 10.0    4613
# 12.0    3781
# 11.0    3661
# 3.0     3549
# 4.0     3452
# 8.0     3393
# 5.0     3337
# 6.0     3151
# Name: month, dtype: int64

# %%
movies.day.value_counts().head(10)
# Out:
# 1.0     5836
# 15.0    1534
# 10.0    1481
# 6.0     1454
# 9.0     1442
# 18.0    1442
# 25.0    1435
# 12.0    1433
# 14.0    1423
# 11.0    1416
# Name: day, dtype: int64

# %% [markdown]
# ### Movie Count by Month<a id='1.5.7_Movie_Count_by_Month'></a>

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
months = list(months)

# %%
_= plt.figure(figsize=(12,6))
_= sns.countplot(x='month', data=movies)
locs, labels=plt.xticks()
_= plt.title('# of movies released each month')
_ = plt.xticks(locs, months)
plt.show()

# %%
movie_month_mean = pd.DataFrame(movies[movies['revenue'] > 1e6].groupby('month')['revenue'].mean())
movie_month_mean['months'] = movie_month_mean.index
_= plt.figure(figsize=(12,6))
_= sns.barplot(x='months', y= 'revenue', data=movie_month_mean)
_= plt.title('Mean Return for each month')
plt.show()

# %%
# approximately 11% of movies in this dataset are drama
movies['genres'].value_counts().head(10)
# Out:
# [Drama]                     4996
# [Comedy]                    3620
# [Documentary]               2721
# []                          2442
# [Drama, Romance]            1300
# [Comedy, Drama]             1133
# [Horror]                     974
# [Comedy, Romance]            930
# [Comedy, Drama, Romance]     593
# [Drama, Comedy]              531
# Name: genres, dtype: int64

# %%
movies['genres'].filter(regex= 'Drama|Comedy').count()
# Out:
# 59

# %%
#print(movies.columns.isin(movies.genres).any())
# every movie record has a diff number of genres 
# returns number of how many genres are listed under each film
movies['num_genres'] = movies['genres'].str.len()
print(movies['num_genres'])
# Out:
# title
# Toy Story                      3
# Jumanji                        3
# Grumpier Old Men               2
# Waiting to Exhale              3
# Father of the Bride Part II    1
#                               ..
# Subdue                         2
# Century of Birthing            1
# Betrayal                       3
# Satan Triumphant               0
# Queerama                       0
# Name: num_genres, Length: 45430, dtype: int64

# %% [markdown]
# ### Number of Zeros by Column<a id='1.5.8_Number_of_Zeros_by_Column'></a>

# %%
#checking to see how many 0s there are in each column
# 0s have a different meaning than null values 
zeros = pd.concat([(movies == 0).astype(int).sum(axis=0), 100 * (movies == 0).astype(int).mean(axis=0)], axis=1)
zeros.columns=['count', '%']
zeros.sort_values(by='%', ascending = False)
# Out:
#                        count          %
# video                  45337  99.795289
# revenue                38032  83.715606
# budget                 36550  80.453445
# vote_average            2995   6.592560
# vote_count              2896   6.374642
# num_genres              2442   5.375303
# runtime                 1558   3.429452
# popularity                66   0.145278
# month                      0   0.000000
# day                        0   0.000000
# year                       0   0.000000
# tagline                    0   0.000000
# status                     0   0.000000
# spoken_languages           0   0.000000
# adult                      0   0.000000
# release_date               0   0.000000
# belongs_to_collection      0   0.000000
# production_companies       0   0.000000
# poster_path                0   0.000000
# overview                   0   0.000000
# original_title             0   0.000000
# original_language          0   0.000000
# imdb_id                    0   0.000000
# id                         0   0.000000
# homepage                   0   0.000000
# genres                     0   0.000000
# production_countries       0   0.000000

# %% [markdown]
# ### Number of Genres per Movie<a id='1.5.9_Number_of_Genres_per_Movie'></a>

# %%
# 32% of movies have only one genre
# 5% doesn't even have a genre listed
# 1.83% of movies have 5 genres 
movies['num_genres'].value_counts(normalize=True) #2442 movies don't have any genre
# Out:
# 1    0.320317
# 2    0.318512
# 3    0.210808
# 4    0.074312
# 0    0.053753
# 5    0.018248
# 6    0.003456
# 7    0.000528
# 8    0.000066
# Name: num_genres, dtype: float64

# %%
movies['num_genres']
# Out:
# title
# Toy Story                      3
# Jumanji                        3
# Grumpier Old Men               2
# Waiting to Exhale              3
# Father of the Bride Part II    1
#                               ..
# Subdue                         2
# Century of Birthing            1
# Betrayal                       3
# Satan Triumphant               0
# Queerama                       0
# Name: num_genres, Length: 45430, dtype: int64

# %%
# couldn't clean this column earlier because of malformed node/string, 6 records had errors
# some values needed to be dropped before this function could be applied on this column
clean_col(movies, 'production_companies')

# %%
# runtime has a different count because of 6 dropped records from earlier & 257 null values
# year, month, day have a different count because release_date had 84 null values & 3 dropped from earlier
movies.describe().transpose()
# Out:
#                 count          mean           std     min          25%  \
# budget        45430.0  4.224828e+06  1.742853e+07     0.0     0.000000
# popularity    45430.0  2.921206e+00  6.006708e+00     0.0     0.385872
# revenue       45430.0  1.121288e+07  6.435213e+07     0.0     0.000000
# runtime       45173.0  9.412430e+01  3.841554e+01     0.0    85.000000
# vote_average  45430.0  5.618329e+00  1.924139e+00     0.0     5.000000
# vote_count    45430.0  1.099360e+02  4.914663e+02     0.0     3.000000
# year          45346.0  1.991883e+03  2.405304e+01  1874.0  1978.000000
# day           45346.0  1.420948e+01  9.283747e+00     1.0     6.000000
# month         45346.0  6.459225e+00  3.628039e+00     1.0     3.000000
# num_genres    45430.0  2.003214e+00  1.130713e+00     0.0     1.000000
#
#                       50%          75%           max
# budget           0.000000     0.000000  3.800000e+08
# popularity       1.127238     3.678128  5.474883e+02
# revenue          0.000000     0.000000  2.787965e+09
# runtime         95.000000   107.000000  1.256000e+03
# vote_average     6.000000     6.800000  1.000000e+01
# vote_count      10.000000    34.000000  1.407500e+04
# year          2001.000000  2010.000000  2.020000e+03
# day             14.000000    22.000000  3.100000e+01
# month            7.000000    10.000000  1.200000e+01
# num_genres       2.000000     3.000000  8.000000e+00

# %% [markdown]
# ## Exploratory Data Analysis<a id='1.6_Exploratory_Data_Analysis'></a>

# %%
# of movies by country 
movies_by_country = pd.DataFrame(movies['production_countries'].value_counts())
movies_by_country['country'] = movies_by_country.index
movies_by_country.columns = ['# of movies', 'country'] 
movies_by_country= movies_by_country.reset_index().drop('index', axis=1)

# %%
movies_by_country.head(10)
# Out:
#    # of movies                     country
# 0        17841  [United States of America]
# 1         6279                          []
# 2         2238            [United Kingdom]
# 3         1653                    [France]
# 4         1354                     [Japan]
# 5         1030                     [Italy]
# 6          840                    [Canada]
# 7          748                   [Germany]
# 8          735                     [India]
# 9          735                    [Russia]

# %%
# of Movies by Language 
num_lang = pd.DataFrame(movies['original_language'].value_counts())
num_lang['language'] = num_lang.index
num_lang.columns = ['# of movies', 'language']
num_lang.head(10)
# Out:
#     # of movies language
# en        32249       en
# fr         2436       fr
# it         1529       it
# ja         1346       ja
# de         1079       de
# es          994       es
# ru          826       ru
# hi          508       hi
# ko          444       ko
# zh          409       zh

# %% [markdown]
# ### Top 10<a id='1.6.1_Top_10'></a>

# %% [markdown]
# #### Languages <a id='1.6.1.1_Languages'></a>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='language', y='# of movies', data=num_lang.iloc[0:10])
plt.show()

# %%
movies['popularity'].plot(logy=True,kind='hist')

# %%
movies['budget'].plot(logy=True, kind='hist')

# %% [markdown]
# #### Popularity<a id='1.6.1.2_Popularity'></a>

# %%
#top 10 movies by popularity
movies[['popularity', 'release_date']].sort_values('popularity', ascending=False).head(10)
# Out:
#                                 popularity release_date
# title
# Minions                         547.488298   2015-06-17
# Wonder Woman                    294.337037   2017-05-30
# Beauty and the Beast            287.253654   2017-03-16
# Baby Driver                     228.032744   2017-06-28
# Big Hero 6                      213.849907   2014-10-24
# Deadpool                        187.860492   2016-02-09
# Guardians of the Galaxy Vol. 2  185.330992   2017-04-19
# Avatar                          185.070892   2009-12-10
# John Wick                       183.870374   2014-10-22
# Gone Girl                       154.801009   2014-10-01

# %% [markdown]
# #### Vote Count <a id='1.6.1.3_Vote_Count'></a>

# %%
#top 10 movies based on vote_count
movies[['vote_count', 'release_date']].sort_values('vote_count', ascending=False).head(10)
# Out:
#                          vote_count release_date
# title
# Inception                   14075.0   2010-07-14
# The Dark Knight             12269.0   2008-07-16
# Avatar                      12114.0   2009-12-10
# The Avengers                12000.0   2012-04-25
# Deadpool                    11444.0   2016-02-09
# Interstellar                11187.0   2014-11-05
# Django Unchained            10297.0   2012-12-25
# Guardians of the Galaxy     10014.0   2014-07-30
# Fight Club                   9678.0   1999-10-15
# The Hunger Games             9634.0   2012-03-12

# %% [markdown]
# #### Grossed <a id='1.6.1.4_Grossed'></a>

# %%
#top 10 grossed movies
movies[movies['revenue']>0][['revenue', 'release_date']].sort_values('revenue', ascending=False).head(10)
# Out:
#                                                    revenue release_date
# title
# Avatar                                        2.787965e+09   2009-12-10
# Star Wars: The Force Awakens                  2.068224e+09   2015-12-15
# Titanic                                       1.845034e+09   1997-11-18
# The Avengers                                  1.519558e+09   2012-04-25
# Jurassic World                                1.513529e+09   2015-06-09
# Furious 7                                     1.506249e+09   2015-04-01
# Avengers: Age of Ultron                       1.405404e+09   2015-04-22
# Harry Potter and the Deathly Hallows: Part 2  1.342000e+09   2011-07-07
# Frozen                                        1.274219e+09   2013-11-27
# Beauty and the Beast                          1.262886e+09   2017-03-16

# %% [markdown]
# #### Budgeted<a id='1.6.1.5_Budgeted'></a>

# %%
#top 10 most expensive movies
movies[movies['budget'] > 0][['budget','revenue', 'release_date']].sort_values('budget', ascending=False).head(10)
# Out:
#                                                   budget       revenue  \
# title
# Pirates of the Caribbean: On Stranger Tides  380000000.0  1.045714e+09
# Pirates of the Caribbean: At World's End     300000000.0  9.610000e+08
# Avengers: Age of Ultron                      280000000.0  1.405404e+09
# Superman Returns                             270000000.0  3.910812e+08
# Transformers: The Last Knight                260000000.0  6.049421e+08
# Tangled                                      260000000.0  5.917949e+08
# John Carter                                  260000000.0  2.841391e+08
# Spider-Man 3                                 258000000.0  8.908716e+08
# The Lone Ranger                              255000000.0  8.928991e+07
# The Dark Knight Rises                        250000000.0  1.084939e+09
#
#                                             release_date
# title
# Pirates of the Caribbean: On Stranger Tides   2011-05-14
# Pirates of the Caribbean: At World's End      2007-05-19
# Avengers: Age of Ultron                       2015-04-22
# Superman Returns                              2006-06-28
# Transformers: The Last Knight                 2017-06-21
# Tangled                                       2010-11-24
# John Carter                                   2012-03-07
# Spider-Man 3                                  2007-05-01
# The Lone Ranger                               2013-07-03
# The Dark Knight Rises                         2012-07-16

# %%
_ = sns.jointplot(x='vote_average', y='vote_count', data=movies)
plt.show()

# %%
# you can notice that all of these listed have very long runtimes and that these are actually mini-series
movies[movies['runtime'] >0][['runtime','release_date']].sort_values('runtime', ascending=False).head(10)
# Out:
#                                      runtime release_date
# title
# Centennial                            1256.0   1978-10-01
# Jazz                                  1140.0   2001-01-09
# Baseball                              1140.0   1994-09-18
# Berlin Alexanderplatz                  931.0   1980-08-28
# Heimat: A Chronicle of Germany         925.0   1984-09-16
# The Story of Film: An Odyssey          900.0   2011-09-03
# Taken                                  877.0   2002-12-02
# The War                                874.0   2007-09-23
# The Roosevelts: An Intimate History    840.0   2014-09-15
# Seventeen Moments in Spring            840.0   1973-01-01

# %% [markdown]
# #### Shortest in Duration<a id='1.6.1.6_Shortest_in_Duration'></a>

# %%
# top 10 shortest movies
movies[movies['runtime'] >0][['runtime','release_date']].sort_values('runtime').head(10)
# Out:
#                                                     runtime release_date
# title
# Mr. Edison at Work in His Chemical Laboratory           1.0   1897-05-31
# Grandma's Reading Glass                                 1.0   1900-11-01
# What Happened on Twenty-Third Street, New York ...      1.0   1901-07-31
# The Magician                                            1.0   1898-01-01
# Panorama pris d'un train en marche                      1.0   1898-01-01
# Divers at Work on the Wreck of the "Maine"              1.0   1898-01-01
# After the Ball                                          1.0   1897-01-01
# Between Calais and Dover                                1.0   1897-01-01
# The Surrender of Tournavos                              1.0   1897-01-01
# Blacksmith Scene                                        1.0   1893-05-08

# %% [markdown]
# ### Movies with One Genre<a id='1.6.2_Movies_with_One_Genre'></a>

# %%
movie_with_one = movies[movies['num_genres'] == 1]

# %%
movie_with_one.describe().transpose()
# Out:
#                 count          mean           std     min          25%  \
# budget        14552.0  1.476017e+06  7.644903e+06     0.0     0.000000
# popularity    14552.0  1.929592e+00  3.115950e+00     0.0     0.247577
# revenue       14552.0  3.710493e+06  2.600311e+07     0.0     0.000000
# runtime       14430.0  9.020312e+01  4.027209e+01     0.0    82.000000
# vote_average  14552.0  5.582992e+00  2.117373e+00     0.0     5.000000
# vote_count    14552.0  4.617159e+01  2.135003e+02     0.0     2.000000
# year          14540.0  1.992693e+03  2.499988e+01  1874.0  1978.000000
# day           14540.0  1.400812e+01  9.327033e+00     1.0     6.000000
# month         14540.0  6.389959e+00  3.657803e+00     1.0     3.000000
# num_genres    14552.0  1.000000e+00  0.000000e+00     1.0     1.000000
#
#                       50%          75%           max
# budget           0.000000     0.000000  1.900000e+08
# popularity       0.766259     2.017234  6.429999e+01
# revenue          0.000000     0.000000  1.506249e+09
# runtime         92.000000   104.000000  1.140000e+03
# vote_average     6.000000     6.900000  1.000000e+01
# vote_count       7.000000    20.000000  9.678000e+03
# year          2004.000000  2012.000000  2.018000e+03
# day             14.000000    22.000000  3.100000e+01
# month            6.000000    10.000000  1.200000e+01
# num_genres       1.000000     1.000000  1.000000e+00

# %%
movie_with_one['genres'].value_counts().plot(kind='barh') # 20 unique single genres
plt.xlabel('Count')
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %%
movie_genres_key=movie_with_one['genres'].apply(lambda x: '_'.join((map(str,x))))

# %%
print(type(movie_genres_key))
# Out:
# <class 'pandas.core.series.Series'>

# %%
sns.set()

# %% [markdown]
# #### Genres vs Vote Average Boxplot<a id='1.6.2.1_Genres_vs_Vote_Average_Boxplot'></a>

# %%
_ = plt.figure(figsize=(10,5))
_ = sns.boxplot(data = movie_with_one, y=movie_genres_key, x='vote_average', orient = "h")
_ = plt.xlabel('Vote Average')
_ = plt.ylabel('Genres')
plt.show()

# %% [markdown]
# #### Genres vs Popularity Boxplot<a id='1.6.2.2_Genres_vs_Popularity_Boxplot'></a>

# %%
#zoomed into the plot for a better view
_ = plt.figure(figsize=(10,5))
_ = sns.boxplot(data = movie_with_one, y=movie_genres_key, x='popularity', orient = "h")
_ = plt.xlabel('Popularity')
_ = plt.ylabel('Genres')
_ = plt.xlim(0,10)
plt.show()

# %% [markdown]
# #### Genres vs Runtime Boxplot<a id='1.6.2.3_Genres_vs_Runtime_Boxplot'></a>

# %%
#zoomed into the plot for a better view
_ = plt.figure(figsize=(10,5))
_ = sns.boxplot(data = movie_with_one, y=movie_genres_key, x='runtime', orient = "h")
_ = plt.xlabel('Runtime')
_ = plt.ylabel('Genres')
_ = plt.xlim(0,200)
plt.show()

# %% [markdown]
# #### Genres vs Vote Count Stripplot<a id='1.6.2.4_Genres_vs_Vote_Count_Stripplot'></a>

# %%
_ = sns.stripplot(data = movie_with_one, y=movie_genres_key, x = 'vote_count', jitter=True)
_ = plt.xlabel('Vote Count')
_ = plt.ylabel('Genres')

# %%
#_ = plt.hist('vote_count','vote_average', bins=(10,10))
#plt.show()

# %% [markdown]
# #### Genres vs Revenue Stripplot<a id='1.6.2.5_Genres_vs_Revenue_Stripplot'></a>

# %%
_ = sns.stripplot(data = movie_with_one, y=movie_genres_key, x='revenue')
_ = plt.xlabel('Revenue')
_ = plt.ylabel('Genres')
plt.show()

# %% [markdown]
# #### Popularity vs Vote Average Linear Regression<a id='1.6.2.6_Popularity_vs_Vote_Average_Linear_Regression'></a>

# %%
_ = sns.lmplot(x='popularity', y='vote_average', data=movie_with_one)
_ = plt.xlabel('Popularity')
_ = plt.ylabel('Vote Average')
_ = plt.title('Popularity vs Vote Average Linear Regression')
plt.show()

# %% [markdown]
# #### Budget vs Vote Average Linear Regression<a id='1.6.2.7_Budget_vs_Vote_Average_Linear_Regression'></a>

# %%
_ = sns.lmplot(x='budget', y='vote_average', data=movie_with_one,palette='Set1')
_ = plt.xlabel('Budget')
_ = plt.ylabel('Vote Average')
_ = plt.title('Budget vs Vote Average Linear Regression')
plt.show()

# %% [markdown]
# #### Vote Count vs Vote Average Linear Regression<a id='1.6.2.8_Vote_Count_vs_Vote_Average_Linear_Regression'></a>

# %%
_ = plt.plot(movie_with_one['vote_count'], movie_with_one['vote_average'], marker='.', linestyle='none')
_ = plt.xlabel('count')
_ = plt.ylabel('Vote Average')
_ = plt.title('Count vs Vote Average')
plt.show()

# %% [markdown]
# #### Popularity vs Revenue Residual Plot<a id='1.6.2.9_Popularity_vs_Revenue_Residual_Plot'></a>

# %%
_ = sns.residplot(x= 'popularity', y= 'revenue', data=movie_with_one, color = 'indianred')
_ = plt.xlabel('Popularity')
_ = plt.ylabel('Revenue')
_ = plt.title('Popularity vs Revenue Residual Plot')

# %% [markdown]
# #### Budget vs Revenue Regression Plot<a id='1.6.2.10_Budget_vs_Revenue_Regression_Plot'></a>

# %%
_ = sns.regplot(x= 'budget', y= 'revenue', data=movie_with_one, color = 'green')
_ = plt.xlabel('Budget')
_ = plt.ylabel('Revenue')
_ = plt.title('Budget vs Revenue Regression Plot')

# %% [markdown]
# #### Popularity vs Vote Average Jointplot<a id='1.6.2.11_Popularity_vs_Vote_Average_Jointplot'></a>

# %%
sns.jointplot(x="popularity", y="vote_average", data=movie_with_one, kind="reg");

# %%
movie_with_two = movies[movies['num_genres'] == 2]

# %%
movie_with_two['genres'].value_counts().head(10).plot(kind ='barh') #303 unique pairs
plt.xlabel('Count')
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %%
stats = pd.DataFrame(movie_with_one.groupby(movie_genres_key).describe())

# %%
stats.columns
# Out:
# MultiIndex([(      'budget', 'count'),
#             (      'budget',  'mean'),
#             (      'budget',   'std'),
#             (      'budget',   'min'),
#             (      'budget',   '25%'),
#             (      'budget',   '50%'),
#             (      'budget',   '75%'),
#             (      'budget',   'max'),
#             (  'popularity', 'count'),
#             (  'popularity',  'mean'),
#             (  'popularity',   'std'),
#             (  'popularity',   'min'),
#             (  'popularity',   '25%'),
#             (  'popularity',   '50%'),
#             (  'popularity',   '75%'),
#             (  'popularity',   'max'),
#             (     'revenue', 'count'),
#             (     'revenue',  'mean'),
#             (     'revenue',   'std'),
#             (     'revenue',   'min'),
#             (     'revenue',   '25%'),
#             (     'revenue',   '50%'),
#             (     'revenue',   '75%'),
#             (     'revenue',   'max'),
#             (     'runtime', 'count'),
#             (     'runtime',  'mean'),
#             (     'runtime',   'std'),
#             (     'runtime',   'min'),
#             (     'runtime',   '25%'),
#             (     'runtime',   '50%'),
#             (     'runtime',   '75%'),
#             (     'runtime',   'max'),
#             ('vote_average', 'count'),
#             ('vote_average',  'mean'),
#             ('vote_average',   'std'),
#             ('vote_average',   'min'),
#             ('vote_average',   '25%'),
#             ('vote_average',   '50%'),
#             ('vote_average',   '75%'),
#             ('vote_average',   'max'),
#             (  'vote_count', 'count'),
#             (  'vote_count',  'mean'),
#             (  'vote_count',   'std'),
#             (  'vote_count',   'min'),
#             (  'vote_count',   '25%'),
#             (  'vote_count',   '50%'),
#             (  'vote_count',   '75%'),
#             (  'vote_count',   'max'),
#             (        'year', 'count'),
#             (        'year',  'mean'),
#             (        'year',   'std'),
#             (        'year',   'min'),
#             (        'year',   '25%'),
#             (        'year',   '50%'),
#             (        'year',   '75%'),
#             (        'year',   'max'),
#             (         'day', 'count'),
#             (         'day',  'mean'),
#             (         'day',   'std'),
#             (         'day',   'min'),
#             (         'day',   '25%'),
#             (         'day',   '50%'),
#             (         'day',   '75%'),
#             (         'day',   'max'),
#             (       'month', 'count'),
#             (       'month',  'mean'),
#             (       'month',   'std'),
#             (       'month',   'min'),
#             (       'month',   '25%'),
#             (       'month',   '50%'),
#             (       'month',   '75%'),
#             (       'month',   'max'),
#             (  'num_genres', 'count'),
#             (  'num_genres',  'mean'),
#             (  'num_genres',   'std'),
#             (  'num_genres',   'min'),
#             (  'num_genres',   '25%'),
#             (  'num_genres',   '50%'),
#             (  'num_genres',   '75%'),
#             (  'num_genres',   'max')],
#            )

# %%
stats.columns = ['budget_count','budget_mean','budget_std','budget_min', 'budget_25p', 'budget_50p', 'budget_75p', 'budget_max',
'popularity_count','popularity_mean','popularity_std','popularity_min', 'popularity_25p', 'popularity_50p', 'popularity_75p', 'popularity_max',
'revenue_count','revenue_mean','revenue_std','revenue_min', 'revenue_25p', 'revenue_50p', 'revenue_75p', 'revenue_max',                 
'runtime_count','runtime_mean','runtime_std','runtime_min', 'runtime_25p', 'runtime_50p', 'runtime_75p', 'runtime_max',
'vote_average_count','vote_average_mean','vote_average_std','vote_average_min', 'vote_average_25p', 'vote_average_50p', 'vote_average_75p', 'vote_average_max',
'vote_count_count', 'vote_count_mean', 'vote_count_std','vote_count_min', 'vote_count_25p', 'vote_count_50p', 'vote_count_75p', 'vote_count_max',
'year_count', 'year_mean', 'year_std', 'year_min', 'year_25p','year_50p', 'year_75p', 'year_max', 
'day_count', 'day_mean', 'day_std', 'day_min', 'day_25p', 'day_50p', 'day_75p', 'day_max', 
'month_count', 'month_mean', 'month_std', 'month_min', 'month_25p','month_50p', 'month_75p', 'month_max',
'num_genres_count','num_genres_mean','num_genres_std','num_genres_min', 'num_genres_25p', 'num_genres_50p', 'num_genres_75p', 'num_genres_max']

# %%
stats
# Out:
#                  budget_count   budget_mean    budget_std  budget_min  \
# genres
# Action                  278.0  4.572418e+06  1.744645e+07         0.0
# Adventure               110.0  7.870664e+06  2.310080e+07         0.0
# Animation               242.0  1.273816e+06  8.001286e+06         0.0
# Comedy                 3620.0  2.308151e+06  9.138128e+06         0.0
# Crime                   134.0  1.676642e+05  1.570883e+06         0.0
# Documentary            2721.0  7.654178e+04  9.729245e+05         0.0
# Drama                  4996.0  1.444392e+06  6.795743e+06         0.0
# Family                   91.0  5.397802e+04  3.222319e+05         0.0
# Fantasy                  51.0  5.214668e+06  2.117119e+07         0.0
# Foreign                  19.0  0.000000e+00  0.000000e+00         0.0
# History                  15.0  1.666667e+06  4.864840e+06         0.0
# Horror                  974.0  8.799475e+05  3.610643e+06         0.0
# Music                   109.0  6.668442e+05  3.544548e+06         0.0
# Mystery                  70.0  1.488571e+05  9.885233e+05         0.0
# Romance                  97.0  7.926804e+05  3.619914e+06         0.0
# Science Fiction         198.0  3.833623e+06  1.769418e+07         0.0
# TV Movie                  7.0  0.000000e+00  0.000000e+00         0.0
# Thriller                465.0  1.844343e+06  7.669162e+06         0.0
# War                      37.0  2.644595e+06  1.154516e+07         0.0
# Western                 318.0  6.413421e+05  4.571157e+06         0.0
#
#                  budget_25p  budget_50p  budget_75p   budget_max  \
# genres
# Action                  0.0         0.0         0.0  190000000.0
# Adventure               0.0         0.0         0.0  150000000.0
# Animation               0.0         0.0         0.0   99000000.0
# Comedy                  0.0         0.0         0.0  112000000.0
# Crime                   0.0         0.0         0.0   18000000.0
# Documentary             0.0         0.0         0.0   35866397.0
# Drama                   0.0         0.0         0.0  130000000.0
# Family                  0.0         0.0         0.0    2200000.0
# Fantasy                 0.0         0.0         0.0  140000000.0
# Foreign                 0.0         0.0         0.0          0.0
# History                 0.0         0.0         0.0   18000000.0
# Horror                  0.0         0.0         0.0   40000000.0
# Music                   0.0         0.0         0.0   30000000.0
# Mystery                 0.0         0.0         0.0    7920000.0
# Romance                 0.0         0.0         0.0   28000000.0
# Science Fiction         0.0         0.0         0.0  178000000.0
# TV Movie                0.0         0.0         0.0          0.0
# Thriller                0.0         0.0         0.0   75000000.0
# War                     0.0         0.0         0.0   68000000.0
# Western                 0.0         0.0         0.0   55000000.0
#
#                  popularity_count  popularity_mean  ...  month_75p  month_max  \
# genres                                              ...
# Action                      278.0         2.781620  ...        9.0       12.0
# Adventure                   110.0         2.672130  ...       10.0       12.0
# Animation                   242.0         1.470265  ...       10.0       12.0
# Comedy                     3620.0         2.319682  ...       10.0       12.0
# Crime                       134.0         0.795429  ...       10.0       12.0
# Documentary                2721.0         0.839767  ...        9.0       12.0
# Drama                      4996.0         2.076730  ...       10.0       12.0
# Family                       91.0         1.196871  ...       11.0       12.0
# Fantasy                      51.0         2.564205  ...       10.0       12.0
# Foreign                      19.0         0.295500  ...       10.0       12.0
# History                      15.0         1.104759  ...        9.0       11.0
# Horror                      974.0         2.592284  ...       10.0       12.0
# Music                       109.0         1.018582  ...       10.0       12.0
# Mystery                      70.0         0.989052  ...       10.0       12.0
# Romance                      97.0         1.250001  ...       10.0       12.0
# Science Fiction             198.0         2.268901  ...       10.0       12.0
# TV Movie                      7.0         0.874082  ...       12.0       12.0
# Thriller                    465.0         2.585835  ...        9.0       12.0
# War                          37.0         2.006420  ...        9.0       12.0
# Western                     318.0         2.112993  ...       10.0       12.0
#
#                  num_genres_count  num_genres_mean  num_genres_std  \
# genres
# Action                      278.0              1.0             0.0
# Adventure                   110.0              1.0             0.0
# Animation                   242.0              1.0             0.0
# Comedy                     3620.0              1.0             0.0
# Crime                       134.0              1.0             0.0
# Documentary                2721.0              1.0             0.0
# Drama                      4996.0              1.0             0.0
# Family                       91.0              1.0             0.0
# Fantasy                      51.0              1.0             0.0
# Foreign                      19.0              1.0             0.0
# History                      15.0              1.0             0.0
# Horror                      974.0              1.0             0.0
# Music                       109.0              1.0             0.0
# Mystery                      70.0              1.0             0.0
# Romance                      97.0              1.0             0.0
# Science Fiction             198.0              1.0             0.0
# TV Movie                      7.0              1.0             0.0
# Thriller                    465.0              1.0             0.0
# War                          37.0              1.0             0.0
# Western                     318.0              1.0             0.0
#
#                  num_genres_min  num_genres_25p  num_genres_50p  \
# genres
# Action                      1.0             1.0             1.0
# Adventure                   1.0             1.0             1.0
# Animation                   1.0             1.0             1.0
# Comedy                      1.0             1.0             1.0
# Crime                       1.0             1.0             1.0
# Documentary                 1.0             1.0             1.0
# Drama                       1.0             1.0             1.0
# Family                      1.0             1.0             1.0
# Fantasy                     1.0             1.0             1.0
# Foreign                     1.0             1.0             1.0
# History                     1.0             1.0             1.0
# Horror                      1.0             1.0             1.0
# Music                       1.0             1.0             1.0
# Mystery                     1.0             1.0             1.0
# Romance                     1.0             1.0             1.0
# Science Fiction             1.0             1.0             1.0
# TV Movie                    1.0             1.0             1.0
# Thriller                    1.0             1.0             1.0
# War                         1.0             1.0             1.0
# Western                     1.0             1.0             1.0
#
#                  num_genres_75p  num_genres_max
# genres
# Action                      1.0             1.0
# Adventure                   1.0             1.0
# Animation                   1.0             1.0
# Comedy                      1.0             1.0
# Crime                       1.0             1.0
# Documentary                 1.0             1.0
# Drama                       1.0             1.0
# Family                      1.0             1.0
# Fantasy                     1.0             1.0
# Foreign                     1.0             1.0
# History                     1.0             1.0
# Horror                      1.0             1.0
# Music                       1.0             1.0
# Mystery                     1.0             1.0
# Romance                     1.0             1.0
# Science Fiction             1.0             1.0
# TV Movie                    1.0             1.0
# Thriller                    1.0             1.0
# War                         1.0             1.0
# Western                     1.0             1.0
#
# [20 rows x 80 columns]

# %%
movie_with_one[movie_genres_key == 'TV Movie']
# Out:
#                     adult belongs_to_collection  budget      genres homepage  \
# title
# David Copperfield   FALSE                   NaN     0.0  [TV Movie]      NaN
# The Pretender 2001  FALSE                   NaN     0.0  [TV Movie]      NaN
# Gangsta Granny      FALSE                   NaN     0.0  [TV Movie]      NaN
# Naughty or Nice     FALSE                   NaN     0.0  [TV Movie]      NaN
# October Kiss        FALSE                   NaN     0.0  [TV Movie]      NaN
# Den radio           FALSE                   NaN     0.0  [TV Movie]      NaN
# The Idiot           FALSE                   NaN     0.0  [TV Movie]      NaN
#
#                         id    imdb_id original_language  \
# title
# David Copperfield   141640  tt0238768                it
# The Pretender 2001   27338  tt0271732                en
# Gangsta Granny      245739  tt3286484                en
# Naughty or Nice     145711  tt2417134                en
# October Kiss        362884  tt5076032                en
# Den radio           143883  tt5952180                ru
# The Idiot           444623  tt0366028                ru
#
#                             original_title  \
# title
# David Copperfield        David Copperfield
# The Pretender 2001      The Pretender 2001
# Gangsta Granny              Gangsta Granny
# Naughty or Nice            Naughty or Nice
# October Kiss                  October Kiss
# Den radio           День Радио (Спектакль)
# The Idiot                            Idiot
#
#                                                              overview  ...  \
# title                                                                  ...
# David Copperfield   An orphan with a rough childhood becomes a bar...  ...
# The Pretender 2001  Jarod reunites with two old friends and unleas...  ...
# Gangsta Granny      A young boy is bored spending time with his du...  ...
# Naughty or Nice     Krissy Kringle receives a delivery intended fo...  ...
# October Kiss        Poppy Summerall is hired near Halloween as a t...  ...
# Den radio                                                         NaN  ...
# The Idiot                      TV miniseries of the Dostoevsky novel.  ...
#
#                     spoken_languages    status  \
# title
# David Copperfield          [Español]  Released
# The Pretender 2001        [Français]  Released
# Gangsta Granny             [English]  Released
# Naughty or Nice            [English]  Released
# October Kiss               [English]  Released
# Den radio                  [Pусский]  Released
# The Idiot                         []  Released
#
#                                                               tagline  video  \
# title
# David Copperfield                                                 NaN  False
# The Pretender 2001  He is a master of disguise. She is a master of...  False
# Gangsta Granny                                                    NaN  False
# Naughty or Nice                                                   NaN  False
# October Kiss                                                      NaN  False
# Den radio                                                         NaN  False
# The Idiot                                                         NaN  False
#
#                    vote_average  vote_count    year   day month num_genres
# title
# David Copperfield           4.8         5.0  2001.0  25.0  12.0          1
# The Pretender 2001          5.4         5.0  2001.0  22.0   1.0          1
# Gangsta Granny              4.8         8.0  2013.0  26.0  12.0          1
# Naughty or Nice             6.1        19.0  2012.0  24.0  12.0          1
# October Kiss                6.5         6.0  2015.0  17.0  10.0          1
# Den radio                   9.0         5.0  2001.0  24.0   3.0          1
# The Idiot                   7.0         1.0  2003.0   1.0   4.0          1
#
# [7 rows x 27 columns]

# %%
_ =plt.errorbar(x = stats.index, y='vote_average_max',data =stats, marker = 'D', linestyle='none')
_ = plt.xticks(rotation=35, ha='right')
_ = plt.yticks(np.arange(7.5,10,0.5)) 
_ = plt.xlabel('Genres')
_ = plt.ylabel('Mean Vote Average')
_ = plt.title("Mean Vote Max By Genre", loc="left", fontsize=15)
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x='vote_average_mean', data = stats)

# %%
mgk=movies['genres'].apply(lambda x: '_'.join((map(str,x))))

# %%
all_movies = movies.groupby(mgk).agg([np.mean, np.std]) 
all_movies
# Out:
#                                          budget               popularity  \
#                                            mean           std       mean
# genres
#                                    4.719209e+04  5.923161e+05   0.304807
# Action                             4.572418e+06  1.744645e+07   2.781620
# Action_Adventure                   1.074973e+07  3.400718e+07   3.673668
# Action_Adventure_Animation         3.500000e+05  1.106797e+06   3.758203
# Action_Adventure_Animation_Comedy  0.000000e+00  0.000000e+00   2.920726
# ...                                         ...           ...        ...
# Western_Science Fiction            2.000000e+06           NaN   1.225217
# Western_TV Movie                   2.500000e+06  3.535534e+06   0.726138
# Western_Thriller                   2.333333e+06  4.041452e+06   2.560855
# Western_War                        0.000000e+00           NaN   0.515080
# Western_War_History_Romance        0.000000e+00           NaN   1.159273
#
#                                                   revenue                \
#                                         std          mean           std
# genres
#                                    0.490416  7.639705e+04  2.505130e+06
# Action                             4.904922  1.080632e+07  9.359374e+07
# Action_Adventure                   6.680113  1.844821e+07  6.415925e+07
# Action_Adventure_Animation         2.459331  0.000000e+00  0.000000e+00
# Action_Adventure_Animation_Comedy  0.836934  0.000000e+00  0.000000e+00
# ...                                     ...           ...           ...
# Western_Science Fiction                 NaN  0.000000e+00           NaN
# Western_TV Movie                   0.769727  0.000000e+00  0.000000e+00
# Western_Thriller                   2.842772  2.049000e+03  3.548972e+03
# Western_War                             NaN  0.000000e+00           NaN
# Western_War_History_Romance             NaN  0.000000e+00           NaN
#
#                                       runtime            vote_average  \
#                                          mean        std         mean
# genres
#                                     69.984349  57.955564     4.239435
# Action                              98.446043  34.475476     5.444964
# Action_Adventure                   101.419355  41.122384     5.164516
# Action_Adventure_Animation          79.100000  26.134056     6.120000
# Action_Adventure_Animation_Comedy  115.000000   7.071068     6.900000
# ...                                       ...        ...          ...
# Western_Science Fiction             87.000000        NaN     5.300000
# Western_TV Movie                   104.000000  22.627417     1.400000
# Western_Thriller                    96.000000   8.544004     4.866667
# Western_War                        105.000000        NaN     6.400000
# Western_War_History_Romance        113.000000        NaN     7.000000
#
#                                              vote_count              \
#                                         std        mean         std
# genres
#                                    3.069244    2.944308    9.940223
# Action                             1.700656   72.863309  348.051030
# Action_Adventure                   1.625052  114.881720  373.998019
# Action_Adventure_Animation         2.241428   73.000000   79.664575
# Action_Adventure_Animation_Comedy  0.000000   17.500000    3.535534
# ...                                     ...         ...         ...
# Western_Science Fiction                 NaN    9.000000         NaN
# Western_TV Movie                   1.979899    2.000000    1.414214
# Western_Thriller                   1.628906   29.000000   36.592349
# Western_War                             NaN    5.000000         NaN
# Western_War_History_Romance             NaN    2.000000         NaN
#
#                                           year                   day  \
#                                           mean        std       mean
# genres
#                                    1989.773909  25.349369  12.487416
# Action                             1995.104317  19.326379  12.708633
# Action_Adventure                   1980.182796  25.502321  14.043011
# Action_Adventure_Animation         2005.900000   6.773314  16.200000
# Action_Adventure_Animation_Comedy  2008.500000   0.707107  15.500000
# ...                                        ...        ...        ...
# Western_Science Fiction            2009.000000        NaN  30.000000
# Western_TV Movie                   2002.500000  13.435029  18.500000
# Western_Thriller                   1983.333333  25.696952  27.666667
# Western_War                        1966.000000        NaN   7.000000
# Western_War_History_Romance        1936.000000        NaN  16.000000
#
#                                                   month           num_genres  \
#                                          std       mean       std       mean
# genres
#                                     9.742157   5.736158  3.829510          0
# Action                              9.338287   5.931655  3.558537          1
# Action_Adventure                    9.845451   6.580645  3.736781          2
# Action_Adventure_Animation          9.624044   8.000000  3.399346          3
# Action_Adventure_Animation_Comedy  13.435029   6.500000  3.535534          4
# ...                                      ...        ...       ...        ...
# Western_Science Fiction                  NaN   8.000000       NaN          2
# Western_TV Movie                   13.435029   4.000000  2.828427          2
# Western_Thriller                    3.511885   4.666667  4.725816          2
# Western_War                              NaN  10.000000       NaN          2
# Western_War_History_Romance              NaN  11.000000       NaN          4
#
#
#                                    std
# genres
#                                    0.0
# Action                             0.0
# Action_Adventure                   0.0
# Action_Adventure_Animation         0.0
# Action_Adventure_Animation_Comedy  0.0
# ...                                ...
# Western_Science Fiction            NaN
# Western_TV Movie                   0.0
# Western_Thriller                   0.0
# Western_War                        NaN
# Western_War_History_Romance        NaN
#
# [4065 rows x 20 columns]

# %%
topmovies = movies.groupby(by=mgk)[['vote_average', 'vote_count']].max().sort_values(by='vote_count', ascending=False).head(10)
_ = sns.stripplot(data = topmovies, y=topmovies.index, x='vote_average', orient="h")
_ = plt.xlabel('Vote Average')
_ = plt.ylabel('Genres')
plt.show()

# %%
movies[mgk.str.contains('Drama')].describe()
# Out:
#              budget    popularity       revenue       runtime  vote_average  \
# count  2.024300e+04  20243.000000  2.024300e+04  20189.000000  20243.000000
# mean   3.460486e+06      3.010777  7.943673e+06    103.050374      5.905888
# std    1.297377e+07      4.422499  4.322779e+07     35.008632      1.696579
# min    0.000000e+00      0.000000  0.000000e+00      0.000000      0.000000
# 25%    0.000000e+00      0.503283  0.000000e+00     90.000000      5.400000
# 50%    0.000000e+00      1.322188  0.000000e+00    100.000000      6.200000
# 75%    0.000000e+00      4.131608  0.000000e+00    114.000000      6.900000
# max    2.500000e+08    154.801009  1.845034e+09   1256.000000     10.000000
#
#          vote_count          year           day         month    num_genres
# count  20243.000000  20234.000000  20234.000000  20234.000000  20243.000000
# mean      96.570074   1990.747652     14.531778      6.600771      2.325890
# std      417.306082     24.427367      9.117530      3.589023      1.074516
# min        0.000000   1893.000000      1.000000      1.000000      1.000000
# 25%        4.000000   1975.000000      7.000000      3.000000      2.000000
# 50%       11.000000   2000.000000     14.000000      7.000000      2.000000
# 75%       37.000000   2010.000000     22.000000     10.000000      3.000000
# max    12269.000000   2018.000000     31.000000     12.000000      8.000000

# %%
all_movies.columns
# Out:
# MultiIndex([(      'budget', 'mean'),
#             (      'budget',  'std'),
#             (  'popularity', 'mean'),
#             (  'popularity',  'std'),
#             (     'revenue', 'mean'),
#             (     'revenue',  'std'),
#             (     'runtime', 'mean'),
#             (     'runtime',  'std'),
#             ('vote_average', 'mean'),
#             ('vote_average',  'std'),
#             (  'vote_count', 'mean'),
#             (  'vote_count',  'std'),
#             (        'year', 'mean'),
#             (        'year',  'std'),
#             (         'day', 'mean'),
#             (         'day',  'std'),
#             (       'month', 'mean'),
#             (       'month',  'std'),
#             (  'num_genres', 'mean'),
#             (  'num_genres',  'std')],
#            )

# %%
sns.set(font_scale = 1)
corr = movies.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)]= True
with sns.axes_style('white'):
    plt.figure(figsize = (10,10))
    _ = sns.heatmap(corr, mask= mask, vmax=.3, square=True, annot=True);

# %%
movies.corr()
# Out:
#                 budget  popularity   revenue   runtime  vote_average  \
# budget        1.000000    0.449682  0.768825  0.134700      0.073496
# popularity    0.449682    1.000000  0.506221  0.129912      0.154357
# revenue       0.768825    0.506221  1.000000  0.103948      0.083883
# runtime       0.134700    0.129912  0.103948  1.000000      0.158192
# vote_average  0.073496    0.154357  0.083883  0.158192      1.000000
# vote_count    0.676699    0.559995  0.812031  0.113555      0.123611
# year          0.131647    0.131634  0.088358  0.078714      0.025829
# day           0.038129    0.051035  0.032208  0.039660      0.032192
# month         0.038710    0.041564  0.031624  0.063551      0.045071
# num_genres    0.193298    0.200612  0.141640  0.153820      0.114546
#
#               vote_count      year       day     month  num_genres
# budget          0.676699  0.131647  0.038129  0.038710    0.193298
# popularity      0.559995  0.131634  0.051035  0.041564    0.200612
# revenue         0.812031  0.088358  0.032208  0.031624    0.141640
# runtime         0.113555  0.078714  0.039660  0.063551    0.153820
# vote_average    0.123611  0.025829  0.032192  0.045071    0.114546
# vote_count      1.000000  0.106797  0.035702  0.033967    0.146425
# year            0.106797  1.000000  0.018550 -0.017248    0.009189
# day             0.035702  0.018550  1.000000  0.136824    0.037087
# month           0.033967 -0.017248  0.136824  1.000000    0.038321
# num_genres      0.146425  0.009189  0.037087  0.038321    1.000000

# %%
movies.corr()['vote_average'].sort_values(ascending=False)
# Out:
# vote_average    1.000000
# runtime         0.158192
# popularity      0.154357
# vote_count      0.123611
# num_genres      0.114546
# revenue         0.083883
# budget          0.073496
# month           0.045071
# day             0.032192
# year            0.025829
# Name: vote_average, dtype: float64

# %%
def scatterplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x=col,  y= 'vote_average', data=movies, alpha=0.5)
        ax.set(xlabel=col, ylabel='Vote Average')
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
features = [col for col in movies.columns if col in ['revenue', 'popularity', 'vote_count', 'runtime', 'budget', 'num_genres', 'month', 'day', 'year']]

# %%
scatterplots(features, ncol=4, figsize=(15, 15))

# %%
_= pd.plotting.scatter_matrix(movies,figsize=[24,10], s = 150, marker = 'D')

# %%
_ = sns.distplot(movies['vote_average'])
plt.show()
# Out:
# C:\Users\sathw\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
_ = sns.distplot(movies['revenue'])
plt.show()
# Out:
# C:\Users\sathw\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Ratings<a id='1.7_Ratings'></a>

# %%
ratings = pd.read_csv('C:/Users/sathw/OneDrive/Desktop/Springboard_work/IMDB-Movie-Ratings/rawdata/ratings.csv', nrows = 2600000)
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings = ratings.rename(columns = {'movieId': 'id'})

# %%
ratings.id = ratings.id.astype(int)

# %%
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit= 's')

# %%
ratings['timestamp']
# Out:
# 0         2015-03-09 22:52:09
# 1         2015-03-09 23:07:15
# 2         2015-03-09 22:52:03
# 3         2015-03-09 22:52:26
# 4         2015-03-09 22:52:36
#                   ...
# 2599995   2003-08-09 11:36:35
# 2599996   2002-12-25 23:21:00
# 2599997   2006-03-20 15:27:47
# 2599998   2003-08-18 15:54:40
# 2599999   2003-08-18 16:00:20
# Name: timestamp, Length: 2600000, dtype: datetime64[ns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600000 entries, 0 to 2599999
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   id         int32
#  2   rating     float64
#  3   timestamp  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1)
# memory usage: 69.4 MB

# %%
ratings.shape
# Out:
# (2600000, 4)

# %%
ratings.userId.nunique()
# Out:
# 27047

# %%
ratings.head(10)
# Out:
#    userId    id  rating           timestamp
# 0       1   110     1.0 2015-03-09 22:52:09
# 1       1   147     4.5 2015-03-09 23:07:15
# 2       1   858     5.0 2015-03-09 22:52:03
# 3       1  1221     5.0 2015-03-09 22:52:26
# 4       1  1246     5.0 2015-03-09 22:52:36
# 5       1  1968     4.0 2015-03-09 23:02:28
# 6       1  2762     4.5 2015-03-09 22:48:20
# 7       1  2918     5.0 2015-03-09 22:53:13
# 8       1  2959     4.0 2015-03-09 22:53:21
# 9       1  4226     4.0 2015-03-09 23:03:48

# %%
#checking how many null values there are for each column/feature
missing = pd.concat([ratings.isnull().sum(), 100 * ratings.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='%', ascending = False)
# Out:
#            count    %
# userId         0  0.0
# id             0  0.0
# rating         0  0.0
# timestamp      0  0.0

# %%
ratings.rating = 2*ratings.rating

# %%
ratings.rating.value_counts().sort_values(ascending=False)
# Out:
# 8.0     703710
# 6.0     535968
# 10.0    376351
# 7.0     310489
# 9.0     214188
# 4.0     176983
# 5.0     123399
# 2.0      83613
# 3.0      38177
# 1.0      37122
# Name: rating, dtype: int64

# %%
ratings.rating.hist(bins=30)
plt.xlabel('rating')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
ratings.rating.mean()
# Out:
# 7.059199615384616

# %%
ratings.rating.std(ddof=0)
# Out:
# 2.112096029184034

# %%
movies['id'] = movies['id'].astype(int)
#pd.to_numeric(movies['id'], errors = 'coerce')
#movies[movies['id']== '8/20/1997']

# %%
movies.shape
# Out:
# (45430, 27)

# %%
movies.id
# Out:
# title
# Toy Story                         862
# Jumanji                          8844
# Grumpier Old Men                15602
# Waiting to Exhale               31357
# Father of the Bride Part II     11862
#                                 ...
# Subdue                         439050
# Century of Birthing            111109
# Betrayal                        67758
# Satan Triumphant               227506
# Queerama                       461257
# Name: id, Length: 45430, dtype: int32

# %%
ratings.id.nunique()
# Out:
# 25560

# %%
ratings.userId.nunique()
# Out:
# 27047

# %%
movies.id.nunique()
# Out:
# 45430

# %% [markdown]
# ## Saving the Data<a id='1.8_Saving_the_Data'></a>

# %%
datapath = 'C:/Users/sathw/OneDrive/Desktop/Springboard_work/IMDB-Movie-Ratings/data'
# renaming the output data directory and re-running this notebook, for example,
# will recreate this (empty) directory and resave the data files.
# NB this is not a substitute for a modern data pipeline, for which there are
# various tools. However, for our purposes here, and often in a "one off" analysis,
# this is useful because we have to deliberately move/delete our data in order
# to overwrite it.
if not os.path.exists(datapath):
    os.mkdir(datapath)

# %%
datapath_moviesdata = os.path.join(datapath, 'movies_cleaned.csv')
if not os.path.exists(datapath_moviesdata):
    movies.to_csv(datapath_moviesdata, index=False)

# %%
datapath_ratingsdata = os.path.join(datapath, 'ratings_cleaned.csv')
if not os.path.exists(datapath_ratingsdata):
    ratings.to_csv(datapath_ratingsdata, index= False)
